# %%
import pandas as pd
import os

# %%
data_path = "../data/raw"

# %%
news = pd.read_csv(os.path.join(data_path, 'news/Semiconductor_News_Raw_20251210.csv'))
print(news.head())
print()
print('-'*60)
print()
print(news.columns)
# Out:
#       keyword                                          title  \
# 0  반도체 수출 데이터  [미리보는 이데일리 신문] 'S대 의사랬는데…' AI가짜광고, 5배 징벌적 ...
# 1  반도체 수출 데이터             [임지선의 틈]정부가 우승자를 선택하는 순간, 패배자가 생긴다
# 2  반도체 수출 데이터          엔비디아, AI칩에 ‘위치 추적’ 심는다…“중국 밀수출 원천 차단”
# 3  반도체 수출 데이터                          국가 에너지 안보를 여론조사에 맡겨서야
# 4  반도체 수출 데이터       원전은 반도체와 맞먹는 수출산업, 그 산업을 죽이면 안된다 [논설실...
#
#                                                 link              date  \
# 0  http://www.edaily.co.kr/news/newspath.asp?news...  2025-12-10 20:50
# 1     https://www.khan.co.kr/article/202512102006025  2025-12-10 20:06
# 2    https://www.dt.co.kr/article/12034520?ref=naver  2025-12-10 19:37
# 3  https://www.ksmnews.co.kr/news/view.php?idx=58...  2025-12-10 19:22
# 4      http://www.fnnews.com/news/202512101832249093  2025-12-10 18:33
#
#                                          description
# 0  합쳐야” -“반도체·데이터센터·SW 아우르는 ‘AI 3강’ 국가 액션플랜 이달 발표...
# 1  일본도 수십조원을 투자해 반도체 공장을 지었다. 대만 TSMC를 키운 건 정부였다....
# ...

# %%
disclosure = pd.read_csv(os.path.join(data_path, 'DART/disclosure_states.csv'))
print(disclosure.head())
print()
print('-'*60)
print()
print(disclosure.columns)
# Out:
#    ticker  corp_code      date        rcept_no            report_nm flr_nm  \
# 0    5930     126380  20200330  20200330003851      사업보고서 (2019.12)   삼성전자
# 1    5930     126380  20200330  20200330000728  임원ㆍ주요주주특정증권등소유상황보고서    안규리
# 2    5930     126380  20200330  20200330000200  임원ㆍ주요주주특정증권등소유상황보고서    이치훈
# 3    5930     126380  20200327  20200327000747  임원ㆍ주요주주특정증권등소유상황보고서    김연성
# 4    5930     126380  20200325  20200325001033    주식등의대량보유상황보고서(일반)   삼성물산
#
#   disclosure_type importance
# 0        PERIODIC       HIGH
# 1           OTHER     NORMAL
# 2           OTHER     NORMAL
# 3           OTHER     NORMAL
# 4           OTHER     NORMAL
#
# ------------------------------------------------------------
#
# Index(['ticker', 'corp_code', 'date', 'rcept_no', 'report_nm', 'flr_nm',
#        'disclosure_type', 'importance'],
#       dtype='object')

# %%
financial = pd.read_csv(os.path.join(data_path, 'DART/financial_states.csv'))
print(financial.head())
print()
print('-'*60)
print()
print(financial.columns)
# Out:
#    ticker  corp_code  year  quarter_code       revenue  operating_income  \
# 0    5930     126380  2020         11013  5.532518e+13      6.447345e+12
# 1    5930     126380  2020         11012  5.296614e+13      8.146292e+12
# 2    5930     126380  2020         11014  6.696416e+13      1.235324e+13
# 3    5930     126380  2020         11011  2.368070e+14      3.599388e+13
# 4    5930     126380  2021         11013  6.538850e+13      9.382868e+12
#
#      net_income profitability_symbol growth_symbol  margin_level
# 0  4.884926e+12           Profitable       Unknown  NormalMargin
# 1  5.555083e+12           Profitable       Unknown  NormalMargin
# 2  9.360693e+12           Profitable       Unknown  NormalMargin
# 3  2.640783e+13           Profitable       Unknown  NormalMargin
# 4  7.141685e+12           Profitable       Unknown  NormalMargin
#
# ------------------------------------------------------------
#
# Index(['ticker', 'corp_code', 'year', 'quarter_code', 'revenue',
# ...

# %%
news.iloc[0,-1]
# Out:
# '합쳐야” -“반도체·데이터센터·SW 아우르는 ‘AI 3강’ 국가 액션플랜 이달 발표” △K반도체 육성 전략... AI 수출 생태계 구축한다 △Global -공급난에 연준 금리인하 덮친다…“내년에도 금·은·동 랠리” -CPI... '

# %%
print(news.iloc[1,-1])
# Out:
# 일본도 수십조원을 투자해 반도체 공장을 지었다. 대만 TSMC를 키운 건 정부였다. 한국도 국가 간 경쟁에서 예외일 수 없다. 달러 벌기 위해 닥치고 수출 대기업엔 규제 풀고, 세제 혜택 독점·수도권 고착화 구조 형성...

# %%
news
# Out:
#             keyword                                          title  \
# 0        반도체 수출 데이터  [미리보는 이데일리 신문] 'S대 의사랬는데…' AI가짜광고, 5배 징벌적 ...
# 1        반도체 수출 데이터             [임지선의 틈]정부가 우승자를 선택하는 순간, 패배자가 생긴다
# 2        반도체 수출 데이터          엔비디아, AI칩에 ‘위치 추적’ 심는다…“중국 밀수출 원천 차단”
# 3        반도체 수출 데이터                          국가 에너지 안보를 여론조사에 맡겨서야
# 4        반도체 수출 데이터       원전은 반도체와 맞먹는 수출산업, 그 산업을 죽이면 안된다 [논설실...
# ...             ...                                            ...
# 7495  모건스탠리 반도체 보고서              모건스탠리 한미 관세협상 긍정적…韓 내년 성장률 0.2%p↑
# 7496  모건스탠리 반도체 보고서                외국계 IB들 한미정상회담으로 韓 경제 불확실성 제거됐다
# 7497  모건스탠리 반도체 보고서      한미 관세 협상 타결에 코스피 추가 상승 기대…성장률 0.2%p 상향 전망
# 7498  모건스탠리 반도체 보고서        '내년 성장률 0.1∼0.2%p↑'...모건스탠리 韓경제 불확실성 해소
# 7499  모건스탠리 반도체 보고서          모건스탠리 韓경제 불확실성 제거…내년 성장률 0.1∼0.2%p 상향
#
#                                                    link              date  \
# 0     http://www.edaily.co.kr/news/newspath.asp?news...  2025-12-10 20:50
# ...
